# %%
import numpy as np
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score, GridSearchCV, KFold, cross_validate
from sklearn.linear_model import Ridge, LogisticRegression, LinearRegression, Lasso, ElasticNet
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE, RFECV
from sklearn.dummy import DummyClassifier
from xgboost import XGBRegressor
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec

# %%
wine_df = pd.read_csv('winemag-data-130k-v2.csv', index_col = 0)
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                  NaN                NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966  Anna Lee C. Iijima                   NaN
# 129967        Paul Gregutt           @paulgwine
# 129968          Roger Voss            @vossroger
# 129969          Roger Voss            @vossroger
# 129970          Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 13 columns]

# %%
wine_df.points.unique()
# Out:
# array([ 87,  86,  85,  88,  92,  91,  90,  89,  83,  82,  81,  80, 100,
#         98,  97,  96,  95,  93,  94,  84,  99], dtype=int64)

# %%
wine_df.isna().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
# wine_df[['region_1','region_2']]
x = zip(wine_df.region_1.tolist(), wine_df.region_2.tolist())
for i in list(x):
    print(i)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ("Montepulciano d'Abruzzo", nan)
# (nan, nan)
# ('Juliénas', nan)
# ('Haut-Médoc', nan)
# ('Bordeaux Blanc', nan)
# ('Sauternes', nan)
# ('Margaux', nan)
# ('Lalande de Pomerol', nan)
# (nan, nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Santa Clara Valley', 'Central Coast')
# ('Washington', 'Washington Other')
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Dundee Hills', 'Willamette Valley')
# ('Mendoza', nan)
# ('Mendoza', nan)
# (nan, nan)
# ('Mendocino', nan)
# (nan, nan)
# ('Morgon', nan)
# ('Willamette Valley', 'Willamette Valley')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Western Australia', nan)
# ('Valtellina Superiore', nan)
# ('Paso Robles', 'Central Coast')
# ('Côtes de Provence', nan)
# (nan, nan)
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# ('Dry Creek Valley', 'Sonoma')
# (nan, nan)
# (nan, nan)
# ('Templeton Gap District', 'Central Coast')
# ('Paso Robles', 'Central Coast')
# ('Horse Heaven Hills', 'Columbia Valley')
# (nan, nan)
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('Côtes de Provence', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Mendocino', nan)
# ('Sta. Rita Hills', 'Central Coast')
# ('Santa Ynez Valley', 'Central Coast')
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# ('Lugana', nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Russian River Valley', 'Sonoma')
# ('New York', 'New York Other')
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('Sonoma Valley', 'Sonoma')
# ('Côtes de Provence', nan)
# ('Côtes de Provence Sainte-Victoire', nan)
# ('Côtes de Provence', nan)
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Orvieto', nan)
# ('Côtes de Castillon', nan)
# ('Bordeaux Supérieur', nan)
# ('Côtes de Provence', nan)
# ("Montepulciano d'Abruzzo", nan)
# ('Colli Aprutini', nan)
# ('California', 'California Other')
# ('Ribera del Duero', nan)
# ('Paso Robles', 'Central Coast')
# (nan, nan)
# ('Rogue Valley', 'Southern Oregon')
# ('Rosso Piceno', nan)
# ('Rosso Piceno', nan)
# ("Montepulciano d'Abruzzo", nan)
# (nan, nan)
# ('Amador County', 'Sierra Foothills')
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Vino de Calidad de Valtiendas', nan)
# ('Carneros', 'Napa-Sonoma')
# ('Paso Robles', 'Central Coast')
# (nan, nan)
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# (nan, nan)
# ('Colline Pescaresi', nan)
# ('South Eastern Australia', nan)
# ('McLaren Vale', nan)
# ('Napa Valley', 'Napa')
# ('Prosecco Superiore di Cartizze', nan)
# ('Rogue Valley', 'Southern Oregon')
# ('Entre-Deux-Mers', nan)
# ('Veneto', nan)
# (nan, nan)
# ('Prosecco Superiore di Cartizze', nan)
# (nan, nan)
# ('North Coast', 'North Coast')
# (nan, nan)
# ('Champagne', nan)
# ('Columbia Gorge (OR)', 'Oregon Other')
# ('Trento', nan)
# ('Rogue Valley', 'Southern Oregon')
# ('Sonoma Valley', 'Sonoma')
# ('Prosecco di Valdobbiadene', nan)
# ('Columbia Gorge (OR)', 'Oregon Other')
# ('Willamette Valley', 'Willamette Valley')
# (nan, nan)
# ('Côtes de Provence', nan)
# (nan, nan)
# (nan, nan)
# ('Lodi', 'Central Valley')
# ('Sonoma County', 'Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('New York', 'New York Other')
# ('Washington', 'Washington Other')
# ('Cortona', nan)
# ('Russian River Valley', 'Sonoma')
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# ('Colorado', nan)
# ('Virginia', nan)
# ('Shenandoah Valley', nan)
# ('Mendoza', nan)
# ('Napa Valley', 'Napa')
# (nan, nan)
# ('California', 'California Other')
# (nan, nan)
# ('Arroyo Seco', 'Central Coast')
# (nan, nan)
# ('Paso Robles', 'Central Coast')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Paso Robles', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Grand Valley', nan)
# ("Coteaux d'Aix-en-Provence", nan)
# ('Côtes de Provence', nan)
# ('Dry Creek Valley', 'Sonoma')
# ('California', 'California Other')
# ('Russian River Valley', 'Sonoma')
# ('Lake County', nan)
# ('Virginia', nan)
# ('Virginia', nan)
# ('Cafayate', nan)
# ('Paso Robles', 'Central Coast')
# ('Chianti Classico', nan)
# ('Vouvray', nan)
# ('Sonoma County', 'Sonoma')
# ('Napa Valley', 'Napa')
# ('Chianti Classico', nan)
# ('Tupungato', nan)
# ('Chianti Classico', nan)
# ('Chianti Classico', nan)
# ('Morellino di Scansano', nan)
# ('Arbois', nan)
# ('California', 'California Other')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Temecula Valley', 'South Coast')
# ('Aloxe-Corton', nan)
# ('Paso Robles', 'Central Coast')
# ('Adelaida District', 'Central Coast')
# ('El Pomar District', 'Central Coast')
# ('Yakima Valley', 'Columbia Valley')
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# ('Los Carneros', 'Napa-Sonoma')
# ('Amarone della Valpolicella Classico', nan)
# (nan, nan)
# ('Cucamonga Valley', 'South Coast')
# ('Edna Valley', 'Central Coast')
# ('Long Island', 'Long Island')
# ('Paso Robles', 'Central Coast')
# ('Ballard Canyon', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# ('Alsace', nan)
# ('Alsace', nan)
# ('Côtes de Provence', nan)
# (nan, nan)
# ('Alsace', nan)
# ('Alsace', nan)
# ('Alsace', nan)
# ('Edna Valley', 'Central Coast')
# ('Amarone della Valpolicella', nan)
# ('Happy Canyon of Santa Barbara', 'Central Coast')
# ('Green Valley', 'Sonoma')
# ('Russian River Valley', 'Sonoma')
# ('Paso Robles', 'Central Coast')
# ('Priorat', nan)
# ('Red Mountain', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Navarra', nan)
# ('Vino de la Tierra de Castilla', nan)
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Napa Valley', 'Napa')
# ('Napa Valley', 'Napa')
# (nan, nan)
# ('Juliénas', nan)
# ('Paso Robles', 'Central Coast')
# ('Priorat', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Red Mountain', 'Columbia Valley')
# ('Calaveras County', 'Sierra Foothills')
# ('Monterey', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# ('Costières de Nîmes', nan)
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Montefalco Sagrantino', nan)
# ('Santa Maria Valley', 'Central Coast')
# ('Arroyo Grande Valley', 'Central Coast')
# ('Cava', nan)
# ('Oregon', 'Oregon Other')
# ('Willamette Valley', 'Willamette Valley')
# ('South Coast', 'South Coast')
# ('Rogue Valley', 'Southern Oregon')
# ('Willamette Valley', 'Willamette Valley')
# ('Monterey', 'Central Coast')
# ('New York', 'New York Other')
# ('Napa Valley', 'Napa')
# ('Napa Valley', 'Napa')
# ('Russian River Valley', 'Sonoma')
# ('Santa Barbara County', 'Central Coast')
# ('Arroyo Grande Valley', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# ('Collio', nan)
# ('Russian River Valley', 'Sonoma')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Central Coast', 'Central Coast')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Arroyo Grande Valley', 'Central Coast')
# ('Alto Adige', nan)
# ('Russian River Valley', 'Sonoma')
# ('Edna Valley', 'Central Coast')
# ('Willamette Valley', 'Willamette Valley')
# ('Beaujolais', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Willamette Valley', 'Willamette Valley')
# ('Santa Barbara County', 'Central Coast')
# ('Tierra de Castilla', nan)
# ('Santa Barbara County', 'Central Coast')
# ('La Mancha', nan)
# ('Cayuga Lake', 'Finger Lakes')
# ('Ribera del Duero', nan)
# ('Rueda', nan)
# ('La Mancha', nan)
# ('Toscana', nan)
# ('Châteauneuf-du-Pape', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Sierra Foothills', 'Sierra Foothills')
# ('El Dorado', 'Sierra Foothills')
# ('Mendoza', nan)
# (nan, nan)
# ('California', 'California Other')
# ('Eola-Amity Hills', 'Willamette Valley')
# (nan, nan)
# ('Lake County', nan)
# ('Napa Valley', 'Napa')
# ('Brouilly', nan)
# ('Côte de Brouilly', nan)
# ('Mendoza', nan)
# ('Paso Robles', 'Central Coast')
# ('California', 'California Other')
# ('Vino de la Tierra de Castilla y León', nan)
# (nan, nan)
# ('Rioja', nan)
# ('Mendoza', nan)
# ('Cava', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Russian River Valley', 'Sonoma')
# ('Green Valley', 'Sonoma')
# ('Napa Valley', 'Napa')
# ('Langhe', nan)
# ('Red Mountain', 'Columbia Valley')
# ('Barolo', nan)
# ('Barolo', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Rattlesnake Hills', 'Columbia Valley')
# ('Pessac-Léognan', nan)
# ('Washington', 'Washington Other')
# ('Russian River Valley', 'Sonoma')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Barolo', nan)
# ('Langhe', nan)
# ('Langhe', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Ribera del Duero', nan)
# ('Chianti Classico', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Sonoma Coast', 'Sonoma')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Sonoma Coast', 'Sonoma')
# (nan, nan)
# ('Santa Maria Valley', 'Central Coast')
# ('Vino Nobile di Montepulciano', nan)
# ('Chianti Classico', nan)
# ('Paso Robles', 'Central Coast')
# ('Champagne', nan)
# ('Margaux', nan)
# ('Yakima Valley', 'Columbia Valley')
# ('Chianti Classico', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('San Luis Obispo County', 'Central Coast')
# ('San Luis Obispo County', 'Central Coast')
# ('Oakville', 'Napa')
# (nan, nan)
# (nan, nan)
# ('Paso Robles', 'Central Coast')
# (nan, nan)
# ('Chianti Rufina', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Arroyo Grande Valley', 'Central Coast')
# ('Rogue Valley', 'Southern Oregon')
# ('Willamette Valley', 'Willamette Valley')
# ('Dry Creek Valley', 'Sonoma')
# ('Bennett Valley', 'Sonoma')
# ('Alicante', nan)
# ('Alicante', nan)
# ('Sta. Rita Hills', 'Central Coast')
# (nan, nan)
# ('Paso Robles', 'Central Coast')
# (nan, nan)
# (nan, nan)
# ('Willamette Valley', 'Willamette Valley')
# ('Dry Creek Valley', 'Sonoma')
# ('Sicilia', nan)
# (nan, nan)
# (nan, nan)
# ('Central Coast', 'Central Coast')
# ('Isonzo del Friuli', nan)
# ('Willamette Valley', 'Willamette Valley')
# ('Muscadet Sèvre et Maine', nan)
# ('Rueda', nan)
# ('Piave', nan)
# ('California', 'California Other')
# ('Bierzo', nan)
# ('Carneros', 'Napa-Sonoma')
# ('Anderson Valley', nan)
# (nan, nan)
# ('Alsace', nan)
# ('Russian River Valley', 'Sonoma')
# ('Vino Nobile di Montepulciano', nan)
# ('Sta. Rita Hills', 'Central Coast')
# ('Vacqueyras', nan)
# (nan, nan)
# ('Mendoza', nan)
# ('Sancerre', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Chianti Classico', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Brunello di Montalcino', nan)
# ('Chianti Classico', nan)
# ('California', 'California Other')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Coteaux du Layon', nan)
# ('Gigondas', nan)
# ('Russian River Valley', 'Sonoma')
# ('Alexander Valley', 'Sonoma')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Mendoza', nan)
# ('Bierzo', nan)
# (nan, nan)
# ('Alsace', nan)
# ('Chianti Classico', nan)
# (nan, nan)
# ('Alto Adige Valle Isarco', nan)
# (nan, nan)
# ('Spain', nan)
# ('Sta. Rita Hills', 'Central Coast')
# ('Châteauneuf-du-Pape', nan)
# ('Sonoma Coast', 'Sonoma')
# (nan, nan)
# ('Mendoza', nan)
# (nan, nan)
# (nan, nan)
# ('Alto Adige', nan)
# ('Russian River Valley', 'Sonoma')
# ('Sonoma Valley', 'Sonoma')
# ('Cahors', nan)
# ('Cahors', nan)
# (nan, nan)
# ('Livermore Valley', 'Central Coast')
# ('Côte de Nuits-Villages', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Paso Robles', 'Central Coast')
# ('Temecula Valley', 'South Coast')
# ('Sonoma County', 'Sonoma')
# ('Templeton Gap District', 'Central Coast')
# ('Cahors', nan)
# ('Cahors', nan)
# ('Paso Robles', 'Central Coast')
# ('Paso Robles', 'Central Coast')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Red Hills Lake County', nan)
# ('Champagne', nan)
# ('Napa Valley', 'Napa')
# ('Chablis', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Alexander Valley', 'Sonoma')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Yakima Valley', 'Columbia Valley')
# (nan, nan)
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('Vernaccia di San Gimignano', nan)
# ('Sta. Rita Hills', 'Central Coast')
# ('Champagne', nan)
# ('Russian River Valley', 'Sonoma')
# ('Napa Valley', 'Napa')
# ('Dry Creek Valley', 'Sonoma')
# (nan, nan)
# ('Willamette Valley', 'Willamette Valley')
# ('Napa Valley', 'Napa')
# ('Willamette Valley', 'Willamette Valley')
# (nan, nan)
# ('Applegate Valley', 'Southern Oregon')
# (nan, nan)
# (nan, nan)
# ('Taurasi', nan)
# ('Dry Creek Valley', 'Sonoma')
# ('Dry Creek Valley', 'Sonoma')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ("Pays d'Oc", nan)
# (nan, nan)
# ('Sonoma County', 'Sonoma')
# ('Lodi', 'Central Valley')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Lodi', 'Central Valley')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Willamette Valley', 'Willamette Valley')
# (nan, nan)
# ('Central Coast', 'Central Coast')
# ('Central Coast', 'Central Coast')
# (nan, nan)
# ('Rioja', nan)
# (nan, nan)
# ('Lodi', 'Central Valley')
# ('Paso Robles', 'Central Coast')
# (nan, nan)
# ('Catalunya', nan)
# ('Ribbon Ridge', 'Willamette Valley')
# ('Côtes de Provence', nan)
# ('Mendoza', nan)
# ('Livermore Valley', 'Central Coast')
# ('Chehalem Mountains', 'Willamette Valley')
# ('Paso Robles', 'Central Coast')
# ('Applegate Valley', 'Southern Oregon')
# ('Arroyo Seco', 'Central Coast')
# ('Elkton Oregon', 'Southern Oregon')
# (nan, nan)
# ('Mendocino', nan)
# (nan, nan)
# ('Mendoza', nan)
# ('Arroyo Seco', 'Central Coast')
# ('Monterey County', 'Central Coast')
# ('Sonoma Valley', 'Sonoma')
# ('Côtes de Provence', nan)
# (nan, nan)
# ('Alexander Valley', 'Sonoma')
# ('Sta. Rita Hills', 'Central Coast')
# ('Paso Robles Willow Creek District', 'Central Coast')
# ('Toro', nan)
# (nan, nan)
# ('Rutherford', 'Napa')
# ('Bandol', nan)
# ('Côtes de Provence', nan)
# ('Cahors', nan)
# ('Côtes de Provence', nan)
# ('Côtes de Provence', nan)
# ('Bandol', nan)
# ('Russian River Valley', 'Sonoma')
# ('Morellino di Scansano', nan)
# ('Toscana', nan)
# ('Morellino di Scansano', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Puligny-Montrachet', nan)
# ('Spring Mountain District', 'Napa')
# (nan, nan)
# ('Pommard', nan)
# (nan, nan)
# ('Toscana', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Livermore Valley', 'Central Coast')
# ('Arroyo Seco', 'Central Coast')
# ('Saint-Romain', nan)
# ('Yakima Valley', 'Columbia Valley')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Toscana', nan)
# ('Maremma Toscana', nan)
# ('Maremma Toscana', nan)
# ('Bourgogne', nan)
# ('Red Mountain', 'Columbia Valley')
# ('Morellino di Scansano', nan)
# (nan, nan)
# (nan, nan)
# ('Alsace', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Paso Robles', 'Central Coast')
# (nan, nan)
# ('Happy Canyon of Santa Barbara', 'Central Coast')
# ('California', 'California Other')
# ('California', 'California Other')
# (nan, nan)
# ('Alsace', nan)
# ('Lake County', nan)
# ('Rosso Conero', nan)
# ('Alsace', nan)
# ('Alsace', nan)
# (nan, nan)
# (nan, nan)
# ('Alexander Valley', 'Sonoma')
# ('California', 'California Other')
# (nan, nan)
# (nan, nan)
# ('Sierra Foothills', 'Sierra Foothills')
# ('Yountville', 'Napa')
# (nan, nan)
# ('Champagne', nan)
# (nan, nan)
# (nan, nan)
# ('Santa Maria Valley', 'Central Coast')
# ('Lodi', 'Central Valley')
# (nan, nan)
# (nan, nan)
# ('Green Valley', 'Sonoma')
# ('Champagne', nan)
# ('California', 'California Other')
# ('Languedoc', nan)
# ('Minervois La Liviniere', nan)
# (nan, nan)
# (nan, nan)
# ('Yountville', 'Napa')
# (nan, nan)
# ('Delle Venezie', nan)
# ('Bordeaux Blanc', nan)
# ('Côtes de Provence', nan)
# ('Sonoma Valley', 'Sonoma')
# ('Paso Robles', 'Central Coast')
# ('Paso Robles', 'Central Coast')
# ('Sonoma County', 'Sonoma')
# ('California', 'California Other')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# ('Dunnigan Hills', 'Central Valley')
# ('Russian River Valley', 'Sonoma')
# ('Delle Venezie', nan)
# ('Delle Venezie', nan)
# ('Napa Valley', 'Napa')
# ('Santa Barbara County', 'Central Coast')
# ('Marche', nan)
# ('North Coast', 'North Coast')
# ('Bordeaux', nan)
# ('Côtes de Provence', nan)
# (nan, nan)
# (nan, nan)
# ('Colli Aprutini', nan)
# ('Bierzo', nan)
# (nan, nan)
# (nan, nan)
# ('Orvieto Classico', nan)
# ("Montepulciano d'Abruzzo", nan)
# ('Sonoma Coast', 'Sonoma')
# ('Bordeaux Blanc', nan)
# ('Sonoma Valley', 'Sonoma')
# ('Yakima Valley', 'Columbia Valley')
# ('Fiano di Avellino', nan)
# ('Sta. Rita Hills', 'Central Coast')
# ('Alexander Valley', 'Sonoma')
# (nan, nan)
# ('North Fork of Long Island', 'Long Island')
# (nan, nan)
# ('Cochise County', nan)
# ('North Fork of Long Island', 'Long Island')
# ('North Fork of Long Island', 'Long Island')
# ('Málaga', nan)
# ('Virginia', nan)
# ('Campania', nan)
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Finger Lakes', 'Finger Lakes')
# ('Russian River Valley', 'Sonoma')
# ('Carneros', 'Napa-Sonoma')
# ('Carneros', 'Napa-Sonoma')
# ('Colli di Salerno', nan)
# ('Irpinia', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Sicilia', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Ancient Lakes', 'Columbia Valley')
# (nan, nan)
# ('Vino de la Tierra de Castilla', nan)
# ('Oak Knoll District', 'Napa')
# ('Paso Robles', 'Central Coast')
# ('Mendoza', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('California', 'California Other')
# ('Columbia Valley (OR)', 'Oregon Other')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Southern Oregon', 'Southern Oregon')
# ('Livermore Valley', 'Central Coast')
# (nan, nan)
# ("Sant'Antimo", nan)
# ('Santa Barbara County', 'Central Coast')
# ('Rioja', nan)
# ('Toscana', nan)
# ('Dry Creek Valley', 'Sonoma')
# ('Rosso di Montalcino', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Brunello di Montalcino', nan)
# ('Willamette Valley', 'Willamette Valley')
# ('Dundee Hills', 'Willamette Valley')
# ('Paso Robles', 'Central Coast')
# ('Somontano', nan)
# ('Brunello di Montalcino', nan)
# ('Santa Barbara County', 'Central Coast')
# ('Sta. Rita Hills', 'Central Coast')
# ('Rogue Valley', 'Southern Oregon')
# ('Brunello di Montalcino', nan)
# ('Rosso di Montalcino', nan)
# ('Rosso di Montalcino', nan)
# ('Brunello di Montalcino', nan)
# ('Rosso di Montalcino', nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Barolo', nan)
# ('Bordeaux', nan)
# ('Bordeaux', nan)
# ('Bordeaux', nan)
# ('Wahluke Slope', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Côtes Catalanes', nan)
# ('Mount Veeder', 'Napa')
# ('California', 'California Other')
# ('Anderson Valley', nan)
# ('Santa Barbara County', 'Central Coast')
# ('Vino Spumante', nan)
# ('Russian River Valley', 'Sonoma')
# ('Barolo', nan)
# ('Bordeaux', nan)
# ('Red Mountain', 'Columbia Valley')
# ('Santa Ynez Valley', 'Central Coast')
# (nan, nan)
# ('Côtes du Rhône Villages', nan)
# ("Dolcetto d'Alba", nan)
# ('California', 'California Other')
# ('Corbières', nan)
# ('Lake County', nan)
# ('Russian River Valley', 'Sonoma')
# ('Bordeaux Supérieur', nan)
# ('Languedoc', nan)
# ('Bordeaux Supérieur', nan)
# ('Puisseguin Saint-Émilion', nan)
# ('Bordeaux Supérieur', nan)
# ('Bordeaux', nan)
# ('Wahluke Slope', 'Columbia Valley')
# ('Mendoza', nan)
# ('Washington', 'Washington Other')
# ('Rutherford', 'Napa')
# ('Passito di Pantelleria', nan)
# ('Napa Valley', 'Napa')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Napa Valley', 'Napa')
# ('Clos de Tart', nan)
# ('Volnay', nan)
# ('Charmes-Chambertin', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Napa Valley', 'Napa')
# ('Napa Valley', 'Napa')
# ('Recioto di Soave', nan)
# ('Mazis-Chambertin', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Santa Ynez Valley', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Beaune', nan)
# ('Pommard', nan)
# ('Sicilia', nan)
# ('Albana di Romagna', nan)
# ('Vosne-Romanée', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Australia', nan)
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('Dry Creek Valley', 'Sonoma')
# (nan, nan)
# ('Côtes de Gascogne', nan)
# ('Rogue Valley', 'Southern Oregon')
# ('California', 'California Other')
# ('Applegate Valley', 'Southern Oregon')
# (nan, nan)
# ('Navarra', nan)
# ('Rogue Valley', 'Southern Oregon')
# ('Valdepeñas', nan)
# ('Chianti Classico', nan)
# (nan, nan)
# ('California', 'California Other')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Antelope Valley of the California High Desert', 'South Coast')
# ('Santa Maria Valley', 'Central Coast')
# (nan, nan)
# (nan, nan)
# ('Dry Creek Valley', 'Sonoma')
# ('Dry Creek Valley', 'Sonoma')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Rioja', nan)
# (nan, nan)
# ('Chehalem Mountains', 'Willamette Valley')
# ('Edna Valley', 'Central Coast')
# ('Sonoma Coast', 'Sonoma')
# ('Eola-Amity Hills', 'Willamette Valley')
# ('Santa Maria Valley', 'Central Coast')
# ('Vino Nobile di Montepulciano', nan)
# ('Brunello di Montalcino', nan)
# ('Haut-Médoc', nan)
# ('Saint-Émilion', nan)
# ('Pessac-Léognan', nan)
# ('Pessac-Léognan', nan)
# ('Pessac-Léognan', nan)
# ('Pessac-Léognan', nan)
# ('Saint-Émilion', nan)
# ('Alsace', nan)
# ('Alsace', nan)
# ('Cava', nan)
# ('Ribeira Sacra', nan)
# ('Sonoma Mountain', 'Sonoma')
# ('Hunter Valley', nan)
# ('Dundee Hills', 'Willamette Valley')
# ('Sonoma Coast', 'Sonoma')
# ('Mendocino County', nan)
# ('Willamette Valley', 'Willamette Valley')
# ('Napa Valley', 'Napa')
# ('Russian River Valley', 'Sonoma')
# ('Russian River Valley', 'Sonoma')
# ('Rioja', nan)
# ('Russian River Valley', 'Sonoma')
# ('Oakville', 'Napa')
# ('Barossa', nan)
# ('Russian River Valley', 'Sonoma')
# ('Napa Valley', 'Napa')
# ('Virginia', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Rutherford', 'Napa')
# ('Yakima Valley', 'Columbia Valley')
# ('Columbia Valley', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Australia', nan)
# ('Amador County', 'Sierra Foothills')
# ('Valpolicella Superiore', nan)
# (nan, nan)
# ('Valpolicella', nan)
# ('Bardolino Chiaretto', nan)
# ('Napa Valley', 'Napa')
# ('California', 'California Other')
# (nan, nan)
# ('California', 'California Other')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Saint-Émilion', nan)
# ('Jurançon Sec', nan)
# ('Côtes de Bourg', nan)
# ('Côtes de Bourg', nan)
# ('Côtes de Bourg', nan)
# ('Blaye Côtes de Bordeaux', nan)
# ('Blaye Côtes de Bordeaux', nan)
# ('Sta. Rita Hills', 'Central Coast')
# ('Mendoza', nan)
# ('Sonoma-Napa', 'Napa-Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ("Sant'Antimo", nan)
# ('Chinon', nan)
# ('Napa Valley', 'Napa')
# ('Saumur', nan)
# (nan, nan)
# ('Carneros', 'Napa-Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Rosso di Montalcino', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Rioja', nan)
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Red Mountain', 'Columbia Valley')
# ('Lodi', 'Central Valley')
# ('California', 'California Other')
# (nan, nan)
# ('Cahors', nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Willamette Valley', 'Willamette Valley')
# ('Corbières-Boutenac', nan)
# ('Calchaquí Valley', nan)
# ('Cahors', nan)
# ('Napa Valley', 'Napa')
# ('Sonoma Coast', 'Sonoma')
# ('Napa Valley', 'Napa')
# (nan, nan)
# ('Dry Creek Valley', 'Sonoma')
# (nan, nan)
# ('Santa Maria Valley', 'Central Coast')
# ('Carneros', 'Napa-Sonoma')
# ('Sagrantino di Montefalco', nan)
# ('Alexander Valley', 'Sonoma')
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Margaret River', nan)
# ('Paso Robles', 'Central Coast')
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Haut-Médoc', nan)
# ('Bordeaux Supérieur', nan)
# (nan, nan)
# ('Washington', 'Washington Other')
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Langhe', nan)
# ('Langhe', nan)
# ('San Benito County', 'Central Coast')
# ('Central Coast', 'Central Coast')
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# ('Alexander Valley', 'Sonoma')
# ('Barolo', nan)
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# (nan, nan)
# ('Verdicchio dei Castelli di Jesi', nan)
# ('Paso Robles', 'Central Coast')
# (nan, nan)
# (nan, nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Offida Pecorino', nan)
# ('Napa Valley', 'Napa')
# ('Bandol', nan)
# ('Bandol', nan)
# ('Dry Creek Valley', 'Sonoma')
# ('Anderson Valley', nan)
# ("Montepulciano d'Abruzzo", nan)
# ('Alsace', nan)
# ('Rosso Piceno', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Lake County', nan)
# ('Verdicchio dei Castelli di Jesi Classico', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Finger Lakes', 'Finger Lakes')
# ('Finger Lakes', 'Finger Lakes')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Alsace', nan)
# ('Washington', 'Washington Other')
# ('Washington', 'Washington Other')
# ('North Coast', 'North Coast')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Mercurey', nan)
# ('Tupungato', nan)
# ('Barolo', nan)
# ('Barossa', nan)
# ('Russian River Valley', 'Sonoma')
# ('Mokelumne River', 'Central Valley')
# ('Chassagne-Montrachet', nan)
# (nan, nan)
# (nan, nan)
# ('Livermore Valley', 'Central Coast')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Chassagne-Montrachet', nan)
# ('Puligny-Montrachet', nan)
# ('Barbaresco', nan)
# (nan, nan)
# ('Tupungato', nan)
# ('Valle de Uco', nan)
# ('Uco Valley', nan)
# (nan, nan)
# ('Savigny-lès-Beaune', nan)
# ('Napa Valley', 'Napa')
# ('Willamette Valley', 'Willamette Valley')
# ('Pouilly-Fuissé', nan)
# ('Mendoza', nan)
# ('Corton', nan)
# ('Echézeaux', nan)
# ('Willamette Valley', 'Willamette Valley')
# (nan, nan)
# ('Willamette Valley', nan)
# ('Paso Robles', 'Central Coast')
# ('Salento', nan)
# ('Puglia', nan)
# ('Puglia', nan)
# ('Virginia', nan)
# ('Cannonau di Sardegna', nan)
# ('Sicilia', nan)
# ('Beaujolais', nan)
# ('Bergerac', nan)
# ('Sicilia', nan)
# ('Napa Valley', 'Napa')
# ('Sicilia', nan)
# ('Chiroubles', nan)
# ('Sicilia', nan)
# ('California', 'California Other')
# ('Willamette Valley', 'Willamette Valley')
# ('Virginia', nan)
# ('Salento', nan)
# ('Salento', nan)
# ('Castillon Côtes de Bordeaux', nan)
# ('Bordeaux Supérieur', nan)
# ('Médoc', nan)
# ('Médoc', nan)
# ('Dry Creek Valley', 'Sonoma')
# ('Beaujolais', nan)
# ('Morgon', nan)
# ('Beaujolais-Villages', nan)
# ('Sicilia', nan)
# ('Sicilia', nan)
# (nan, nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Cahors', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Santa Barbara County', 'Central Coast')
# ('Oak Knoll District', 'Napa')
# ('Russian River Valley', 'Sonoma')
# ('Torgiano', nan)
# ('Sonoma Valley', 'Sonoma')
# ('Willamette Valley', 'Willamette Valley')
# ('Oak Knoll District', 'Napa')
# ('Santa Cruz Mountains', 'Central Coast')
# (nan, nan)
# ('Cahors', nan)
# ('Carneros', 'Napa-Sonoma')
# ('Napa Valley', 'Napa')
# ('Red Hills Lake County', nan)
# ('Willamette Valley', 'Willamette Valley')
# ('Mendoza', nan)
# ('Sonoma Valley', 'Sonoma')
# (nan, nan)
# ('Dundee Hills', 'Willamette Valley')
# ('Lake County', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Sierra Foothills', 'Sierra Foothills')
# (nan, nan)
# ('Amarone della Valpolicella Classico', nan)
# ('San Diego County', 'South Coast')
# ('North Coast', 'North Coast')
# (nan, nan)
# ('Sonoma Valley', 'Sonoma')
# ('Mendoza', nan)
# ('Red Hills Lake County', nan)
# ('Carneros', 'Napa-Sonoma')
# ('Paso Robles', 'Central Coast')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Russian River Valley', 'Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Sta. Rita Hills', 'Central Coast')
# ('Finger Lakes', 'Finger Lakes')
# ('Finger Lakes', 'Finger Lakes')
# ('Meursault', nan)
# ('Nuits-St.-Georges', nan)
# ('Vouvray', nan)
# ('Sancerre', nan)
# ('Viré-Clessé', nan)
# ('Pouilly-Fuissé', nan)
# ('Sancerre', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Mendoza', nan)
# ('Napa Valley', 'Napa')
# ('Carmel Valley', 'Central Coast')
# ('Dry Creek Valley', 'Sonoma')
# ('Hudson River Region', 'New York Other')
# ('Okanagan Valley', nan)
# ('Okanagan Valley', nan)
# ('Dry Creek Valley', 'Sonoma')
# ('Santa Maria Valley', 'Central Coast')
# ('Dry Creek Valley', 'Sonoma')
# ('Rioja', nan)
# ('Sonoma County', 'Sonoma')
# ('Sonoma-Napa-Lake', 'North Coast')
# ('Brunello di Montalcino', nan)
# ('Russian River Valley', 'Sonoma')
# ('Adelaida District', 'Central Coast')
# ('Okanagan Valley', nan)
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Mount Veeder', 'Napa')
# ('Sta. Rita Hills', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Anderson Valley', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Chianti Classico', nan)
# ('Brunello di Montalcino', nan)
# ('Finger Lakes', 'Finger Lakes')
# (nan, nan)
# ('Santa Barbara County', 'Central Coast')
# ('Sta. Rita Hills', 'Central Coast')
# ('Sta. Rita Hills', 'Central Coast')
# ('Sonoma Coast', 'Sonoma')
# ('Rioja', nan)
# ('Sancerre', nan)
# ('Red Mountain', 'Columbia Valley')
# (nan, nan)
# ('Coteaux du Giennois', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Brunello di Montalcino', nan)
# (nan, nan)
# (nan, nan)
# ('Paso Robles', 'Central Coast')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Yakima Valley', 'Columbia Valley')
# ('Maremma Toscana', nan)
# ('Côtes du Rhône', nan)
# ('Chianti', nan)
# ('Vino Nobile di Montepulciano', nan)
# ('Chianti Classico', nan)
# ('Chianti Classico', nan)
# ('Sonoma Valley', 'Sonoma')
# ('Brunello di Montalcino', nan)
# ('Brunello di Montalcino', nan)
# ('Priorat', nan)
# ('Cava', nan)
# ('Red Mountain', 'Columbia Valley')
# ('Savigny-lès-Beaune', nan)
# ('Okanagan Valley', nan)
# ('Santa Maria Valley', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# ('Wahluke Slope', 'Columbia Valley')
# (nan, nan)
# ('Maremma Toscana', nan)
# ('Alto Adige', nan)
# (nan, nan)
# ('Alto Adige', nan)
# (nan, nan)
# ('North Coast', 'North Coast')
# ('Calchaquí Valley', nan)
# ('Paso Robles', 'Central Coast')
# ('Collio', nan)
# ('Alsace', nan)
# ('Dundee Hills', 'Willamette Valley')
# ('Valle de Uco', nan)
# ('Collio', nan)
# ('Alto Adige', nan)
# ('Alto Adige', nan)
# (nan, nan)
# (nan, nan)
# ('Alto Adige', nan)
# ('Alto Adige', nan)
# ('Rogue Valley', 'Southern Oregon')
# ('Old Mission Peninsula', nan)
# ('Venezia Giulia', nan)
# (nan, nan)
# (nan, nan)
# ('Bierzo', nan)
# ('Ribera del Duero', nan)
# ('Alsace', nan)
# (nan, nan)
# ('McLaren Vale', nan)
# ('Rías Baixas', nan)
# ('Old Mission Peninsula', nan)
# ('Médoc', nan)
# ('Graves', nan)
# ('Médoc', nan)
# ('Haut-Médoc', nan)
# ('Médoc', nan)
# ('Saint-Estèphe', nan)
# ('Canon-Fronsac', nan)
# ('Wahluke Slope', 'Columbia Valley')
# ('Paso Robles', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('North Fork of Long Island', 'Long Island')
# ('California', 'California Other')
# ('Tupungato', nan)
# ('Paso Robles', 'Central Coast')
# ('California', 'California Other')
# ('North Fork of Long Island', 'Long Island')
# ('Russian River Valley', 'Sonoma')
# ('Paso Robles', 'Central Coast')
# ('Moulis-en-Médoc', nan)
# ('Haut-Médoc', nan)
# ('Saint-Estèphe', nan)
# ('California', 'California Other')
# ('Contra Costa County', 'Central Coast')
# ('Mendoza', nan)
# ('Navarra', nan)
# ('Mendocino', nan)
# ('Haut-Médoc', nan)
# ('Montagne-Saint-Émilion', nan)
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Trentino', nan)
# ('Santa Lucia Highlands', 'Central Coast')
# ('Trentino', nan)
# (nan, nan)
# ('Carneros', 'Napa-Sonoma')
# ('Verdicchio dei Castelli di Jesi Classico Superiore', nan)
# ('Sicilia', nan)
# (nan, nan)
# ('Teroldego Rotaliano', nan)
# ('Orange', nan)
# ('California', 'California Other')
# ('Orcia', nan)
# ('Yakima Valley', 'Columbia Valley')
# ('Petit Chablis', nan)
# ('Green Valley', 'Sonoma')
# ('Chianti', nan)
# ('California', 'California Other')
# (nan, nan)
# ('Chablis', nan)
# ("Trebbiano d'Abruzzo", nan)
# ('Campania', nan)
# ('Chianti', nan)
# ('Chablis', nan)
# (nan, nan)
# ('Mendoza', nan)
# (nan, nan)
# ('Cava', nan)
# ('Arroyo Grande Valley', 'Central Coast')
# (nan, nan)
# ('Prosecco di Conegliano e Valdobbiadene', nan)
# ('Sonoma County', 'Sonoma')
# ('Alexander Valley', 'Sonoma')
# ('Alsace', nan)
# ('Napa Valley', 'Napa')
# ('Paso Robles', 'Central Coast')
# ('Lodi', 'Central Valley')
# ('Rías Baixas', nan)
# ('Vin Mousseux', nan)
# ('Prosecco di Valdobbiadene', nan)
# ('Prosecco di Conegliano e Valdobbiadene', nan)
# ('Penedès', nan)
# ('Rioja', nan)
# ('Lodi', 'Central Valley')
# ('Monterey County', 'Central Coast')
# (nan, nan)
# ('Prosecco di Conegliano e Valdobbiadene', nan)
# ('Alexander Valley', 'Sonoma')
# (nan, nan)
# ('Anderson Valley', nan)
# ('Saint-Aubin', nan)
# ('Yakima Valley', 'Columbia Valley')
# (nan, nan)
# ('Bolgheri', nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Sonoma Coast', 'Sonoma')
# ('Santa Maria Valley', 'Central Coast')
# ('Santa Ynez Valley', 'Central Coast')
# ('Yakima Valley', 'Columbia Valley')
# ('Bolgheri', nan)
# ('Russian River Valley', 'Sonoma')
# ('Russian River Valley', 'Sonoma')
# ('Carneros', 'Napa-Sonoma')
# ('Maremma Toscana', nan)
# ('Sonoma Coast', 'Sonoma')
# (nan, nan)
# ('Maremma Toscana', nan)
# ('Santa Barbara County', 'Central Coast')
# (nan, nan)
# ('Toscana', nan)
# ('Fort Ross-Seaview', 'Sonoma')
# ('Morellino di Scansano', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Sta. Rita Hills', 'Central Coast')
# ('Sonoma Coast', 'Sonoma')
# ('North Fork of Long Island', 'Long Island')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Ribera del Duero', nan)
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('Castillon Côtes de Bordeaux', nan)
# ('Lalande de Pomerol', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Toro', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Santa Barbara County', 'Central Coast')
# (nan, nan)
# (nan, nan)
# ('Ribera del Duero', nan)
# ('California', 'California Other')
# ('Chianti Classico', nan)
# (nan, nan)
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('North Coast', 'North Coast')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Sonoma Coast', 'Sonoma')
# (nan, nan)
# ('Venezia Giulia', nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Côtes du Rhône Villages', nan)
# (nan, nan)
# ('Applegate Valley', 'Southern Oregon')
# ('Chalone', 'Central Coast')
# ('Willamette Valley', 'Willamette Valley')
# ('Willamette Valley', 'Willamette Valley')
# (nan, nan)
# ('Rutherford', 'Napa')
# ('Napa Valley', 'Napa')
# ('Napa Valley', 'Napa')
# ('Willamette Valley', 'Willamette Valley')
# (nan, nan)
# ('Châteauneuf-du-Pape', nan)
# ('Châteauneuf-du-Pape', nan)
# ('Edna Valley', 'Central Coast')
# ('Niagara Peninsula', nan)
# (nan, nan)
# ('Jurançon', nan)
# ('Médoc', nan)
# ('Bordeaux Supérieur', nan)
# ('Côtes de Bergerac', nan)
# (nan, nan)
# ('Sicilia', nan)
# ('Jurançon Sec', nan)
# ('Fleurie', nan)
# ('Sicilia', nan)
# ('Sicilia', nan)
# ('Napa Valley', 'Napa')
# ('Lalande de Pomerol', nan)
# ('Médoc', nan)
# ('Médoc', nan)
# ('Ribbon Ridge', 'Willamette Valley')
# (nan, nan)
# ('Etna', nan)
# (nan, nan)
# ('Sicilia', nan)
# ('Rogue Valley', 'Southern Oregon')
# ('Santa Barbara County', 'Central Coast')
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# ('Mendocino County', nan)
# ('Virginia', nan)
# ('Napa Valley', 'Napa')
# ('Napa Valley', 'Napa')
# ('Green Valley', 'Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Sonoma Valley', 'Sonoma')
# ('Jurançon', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Côtes de Gascogne', nan)
# ('Greco di Tufo', nan)
# ('Napa Valley', 'Napa')
# ('Dry Creek Valley', 'Sonoma')
# ('Russian River Valley', 'Sonoma')
# ('Lacryma Christi del Vesuvio', nan)
# ('Oakville', 'Napa')
# ('Côtes du Rhône', nan)
# ('Río Negro Valley', nan)
# ('Mendoza', nan)
# ('Arroyo Seco', 'Central Coast')
# ('Gutturnio Colli Piacentini', nan)
# (nan, nan)
# ('Salta', nan)
# ('Edna Valley', 'Central Coast')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Napa County', 'Napa')
# ('Bordeaux Rosé', nan)
# ('Bordeaux Blanc', nan)
# ('Bordeaux Blanc', nan)
# ('Bordeaux Rosé', nan)
# (nan, nan)
# (nan, nan)
# ('Alexander Valley', 'Sonoma')
# ('Bordeaux Blanc', nan)
# ('Navarra', nan)
# ('Napa Valley', 'Napa')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Bordeaux Rosé', nan)
# ('Bordeaux Rosé', nan)
# ('Bordeaux Rosé', nan)
# ('Bordeaux Rosé', nan)
# (nan, nan)
# (nan, nan)
# ('Alella', nan)
# (nan, nan)
# ('Castel del Monte', nan)
# ('Napa Valley', 'Napa')
# (nan, nan)
# (nan, nan)
# ('North Coast', 'North Coast')
# ('Uco Valley', nan)
# ('Napa Valley', 'Napa')
# ('Napa Valley', 'Napa')
# ('Rías Baixas', nan)
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('Mendoza', nan)
# ('Hunter Valley', nan)
# (nan, nan)
# ('Cadillac', nan)
# ('Vino de la Tierra de Castilla y León', nan)
# ('Mendoza', nan)
# ('Salta', nan)
# (nan, nan)
# ('Colli Orientali del Friuli', nan)
# (nan, nan)
# ('Santa Cruz Mountains', 'Central Coast')
# (nan, nan)
# ('California', 'California Other')
# ('Shenandoah Valley (CA)', 'Sierra Foothills')
# ('South Eastern Australia', nan)
# ('Clare Valley', nan)
# ('Mendoza', nan)
# (nan, nan)
# (nan, nan)
# ('Ribera del Duero', nan)
# (nan, nan)
# ('Crémant de Bourgogne', nan)
# ('Crémant de Bourgogne', nan)
# ('Bourgogne', nan)
# ('Central Coast', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Finger Lakes', 'Finger Lakes')
# ('Sonoma Coast', 'Sonoma')
# ('Finger Lakes', 'Finger Lakes')
# ('Menetou-Salon', nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Chianti Classico', nan)
# ('Sancerre', nan)
# ('Brunello di Montalcino', nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Chianti Classico', nan)
# ('Russian River Valley', 'Sonoma')
# ('Napa Valley', 'Napa')
# ('Sancerre', nan)
# ('Sancerre', nan)
# ('Brunello di Montalcino', nan)
# ('Sancerre', nan)
# (nan, nan)
# ('California', 'California Other')
# ('Okanagan Valley', nan)
# ('Valencia', nan)
# ('Utiel-Requena', nan)
# ('Valencia', nan)
# ('Mount Veeder', 'Napa')
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Central Coast', 'Central Coast')
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Carneros', 'Napa-Sonoma')
# (nan, nan)
# ('Cahors', nan)
# ('Yakima Valley', 'Columbia Valley')
# ('California', 'California Other')
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Napa Valley', 'Napa')
# ('Sierra Foothills', 'Sierra Foothills')
# ('Sonoma Coast', 'Sonoma')
# ('Monterey', 'Central Coast')
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('Napa Valley', 'Napa')
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Monterey County', 'Central Coast')
# ('Alexander Valley', 'Sonoma')
# ('Arroyo Seco', 'Central Coast')
# (nan, nan)
# ("Barbera d'Asti Superiore", nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ("Dolcetto d'Alba", nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Gavi', nan)
# ('Barbera del Monferrato', nan)
# ("Barbera d'Asti", nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Santa Lucia Highlands', 'Central Coast')
# (nan, nan)
# ('Barbera del Monferrato Superiore', nan)
# ("Barbera d'Alba", nan)
# (nan, nan)
# ('South Australia', nan)
# ('Santa Ynez Valley', 'Central Coast')
# (nan, nan)
# ('Carneros', 'Napa-Sonoma')
# ('Barbera del Monferrato', nan)
# ('Napa Valley', 'Napa')
# ('Livermore Valley', 'Central Coast')
# ("Barbera d'Alba", nan)
# (nan, nan)
# ('Sonoma County-Santa Barbara County', 'California Other')
# ("Barbera d'Asti", nan)
# ('Barbaresco', nan)
# (nan, nan)
# (nan, nan)
# ('Pouilly-Fuissé', nan)
# ('Barbaresco', nan)
# ('Barbaresco', nan)
# (nan, nan)
# ('Barolo', nan)
# ('Carneros', 'Napa-Sonoma')
# (nan, nan)
# ('Chambolle-Musigny', nan)
# (nan, nan)
# ('Puligny-Montrachet', nan)
# ('Vosne-Romanée', nan)
# (nan, nan)
# ('Dundee Hills', 'Willamette Valley')
# ('Dry Creek Valley', 'Sonoma')
# ('Sonoma Coast', 'Sonoma')
# ('Beaune', nan)
# ('Rutherford', 'Napa')
# ('Napa Valley', 'Napa')
# ('Yarra Valley', nan)
# ('McLaren Vale', nan)
# ('Dundee Hills', 'Willamette Valley')
# ('Dundee Hills', 'Willamette Valley')
# ('Edna Valley', 'Central Coast')
# ('Barbaresco', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Chassagne-Montrachet', nan)
# ('Vin de France', nan)
# ('Pompeiano', nan)
# ('Virginia', nan)
# ('Coombsville', 'Napa')
# ('Terre del Volturno', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Terre Siciliane', nan)
# ('Virginia', nan)
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Alsace', nan)
# ('Sonoma County', 'Sonoma')
# ('Coteaux Varois en Provence', nan)
# (nan, nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Virginia', nan)
# ('Navarra', nan)
# ('Alsace', nan)
# ('Shenandoah Valley', nan)
# (nan, nan)
# ('Virginia', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Knights Valley', 'Sonoma')
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Sonoma Coast', 'Sonoma')
# (nan, nan)
# ('Middleburg', nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Mendoza', nan)
# ('Mendoza', nan)
# (nan, nan)
# ('Vin de France', nan)
# ('Temecula Valley', 'South Coast')
# ('Menetou-Salon', nan)
# ('South Eastern Australia', nan)
# ('Rogue Valley', 'Southern Oregon')
# ('Monticello', nan)
# ('Vin de France', nan)
# (nan, nan)
# ('Mendoza', nan)
# ('Vin de France', nan)
# ('Vin de France', nan)
# ('Mediterranée', nan)
# (nan, nan)
# ('Mendoza', nan)
# ('Maipú', nan)
# (nan, nan)
# (nan, nan)
# ('Mendoza', nan)
# ('Middleburg', nan)
# ('Russian River Valley', 'Sonoma')
# ('Colorado', nan)
# ('South Eastern Australia', nan)
# ('Ribera del Duero', nan)
# (nan, nan)
# ('Calistoga', 'Napa')
# ('Toro', nan)
# ('Red Mountain', 'Columbia Valley')
# (nan, nan)
# ('Virginia', nan)
# ('Yakima Valley', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Greco di Tufo', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Finger Lakes', 'Finger Lakes')
# ('Vesuvio', nan)
# ('Santa Cruz Mountains', 'Central Coast')
# ('Red Mountain', 'Columbia Valley')
# ('Mendoza', nan)
# ('Ribera del Duero', nan)
# ('Fiano di Avellino', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Campo de Borja', nan)
# ('Seneca Lake', 'Finger Lakes')
# ('Seneca Lake', 'Finger Lakes')
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Russian River Valley', 'Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Oakville', 'Napa')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Washington', 'Washington Other')
# ('Yarra Valley', nan)
# ('Sicilia', nan)
# ('Virginia', nan)
# ('Paso Robles', 'Central Coast')
# ('Finger Lakes', 'Finger Lakes')
# ('Alexander Valley', 'Sonoma')
# ('Virginia', nan)
# ('New Mexico', nan)
# ('Vin de Pays des Côtes de Gascogne', nan)
# ('Mendoza', nan)
# ('Paso Robles', 'Central Coast')
# ('Tupungato', nan)
# ('Finger Lakes', 'Finger Lakes')
# ("Montepulciano d'Abruzzo", nan)
# ('Mendoza', nan)
# ('Vouvray', nan)
# ('Paso Robles', 'Central Coast')
# ('South Eastern Australia', nan)
# ('Alexander Valley', 'Sonoma')
# ('South Eastern Australia', nan)
# ('Côtes du Rhône', nan)
# ('Wahluke Slope', 'Columbia Valley')
# ('Spain', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Bordeaux Supérieur', nan)
# ('Côtes de Bordeaux', nan)
# ('Bordeaux Blanc', nan)
# ('Paso Robles', 'Central Coast')
# ('Muscadet Sèvre et Maine', nan)
# ('Costières de Nîmes', nan)
# ('Rioja', nan)
# ('Rueda', nan)
# ('North Fork of Long Island', 'Long Island')
# ('Rioja', nan)
# ('Knights Valley', 'Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Muscadet Sèvre et Maine', nan)
# ('Luberon', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('North Fork of Long Island', 'Long Island')
# ('Horse Heaven Hills', 'Columbia Valley')
# (nan, nan)
# ('Sonoma County', 'Sonoma')
# ('Lodi', 'Central Valley')
# ('Rioja', nan)
# ('Barolo', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Lodi', 'Central Valley')
# ('North Fork of Long Island', 'Long Island')
# (nan, nan)
# ('Santa Lucia Highlands', 'Central Coast')
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# ('Russian River Valley', 'Sonoma')
# ('Central Coast', 'Central Coast')
# ('Central Coast', 'Central Coast')
# ('Monterey County', 'Central Coast')
# ('Santa Cruz Mountains', 'Central Coast')
# ('California', 'California Other')
# ('California', 'California Other')
# ('Arroyo Seco', 'Central Coast')
# ('Paso Robles', 'Central Coast')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Monterey County', 'Central Coast')
# ('Paso Robles', 'Central Coast')
# ('California', 'California Other')
# ('Virginia', nan)
# (nan, nan)
# ('California', 'California Other')
# (nan, nan)
# ('Virginia', nan)
# ('California', 'California Other')
# ('California', 'California Other')
# ('Central Coast', 'Central Coast')
# ('Virginia', nan)
# (nan, nan)
# ('Paso Robles', 'Central Coast')
# ('Sonoma Coast', 'Sonoma')
# (nan, nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Finger Lakes', 'Finger Lakes')
# ('Central Coast', 'Central Coast')
# ('Paso Robles', 'Central Coast')
# ('Friuli Grave', nan)
# ('Sonoma Valley', 'Sonoma')
# ('Willamette Valley', 'Willamette Valley')
# ('Delle Venezie', nan)
# ('Delle Venezie', nan)
# (nan, nan)
# ('Friuli Grave', nan)
# ('Livermore Valley', 'Central Coast')
# ('New Mexico', nan)
# ('Dry Creek Valley', 'Sonoma')
# ('Missouri', nan)
# ('Russian River Valley', 'Sonoma')
# ('Southern Oregon', 'Southern Oregon')
# ('Napa Valley', 'Napa')
# ('Sta. Rita Hills', 'Central Coast')
# ('Paso Robles', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# ('Sonoma Coast', 'Sonoma')
# ('Snipes Mountain', 'Columbia Valley')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Santa Lucia Highlands', 'Central Coast')
# (nan, nan)
# (nan, nan)
# ('Eola-Amity Hills', 'Willamette Valley')
# ('Paso Robles', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Carmel Valley', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Green Valley', 'Sonoma')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Green Valley', 'Sonoma')
# ('Russian River Valley', 'Sonoma')
# ('Napa Valley', 'Napa')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Sonoma Coast', 'Sonoma')
# ('Ribbon Ridge', 'Willamette Valley')
# ('Ribera del Duero', nan)
# ('Western Australia', nan)
# (nan, nan)
# (nan, nan)
# ('Willamette Valley', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Morellino di Scansano', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Corse', nan)
# ('Red Hills Lake County', nan)
# ("Barbera d'Asti Superiore", nan)
# ('Sierra Foothills', 'Sierra Foothills')
# ('Rueda', nan)
# ('Yakima Valley', 'Columbia Valley')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Barolo', nan)
# ('Sancerre', nan)
# ('Cava', nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Santa Barbara County', 'Central Coast')
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Napa Valley', 'Napa')
# ('Edna Valley', 'Central Coast')
# ('Ribeira Sacra', nan)
# (nan, nan)
# ('Santa Cruz Mountains', 'Central Coast')
# ('Finger Lakes', 'Finger Lakes')
# ('Alicante', nan)
# ('Alicante', nan)
# ('Washington', 'Washington Other')
# ('Napa Valley', 'Napa')
# ('Bolgheri Superiore', nan)
# ('Barbaresco', nan)
# ('Jumilla', nan)
# ('Okanagan Valley', nan)
# ('Morgon', nan)
# ('Temecula Valley', 'South Coast')
# ('Valle de Uco', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# ('Santa Maria Valley', 'Central Coast')
# ('Sta. Rita Hills', 'Central Coast')
# ('Carneros', 'Napa-Sonoma')
# ('Champagne', nan)
# ('Eola-Amity Hills', 'Willamette Valley')
# ('Willamette Valley', 'Willamette Valley')
# ('Elkton Oregon', 'Southern Oregon')
# ('Napa Valley', 'Napa')
# ('Santa Cruz Mountains', 'Central Coast')
# ('Champagne', nan)
# (nan, nan)
# ('Champagne', nan)
# ('Conegliano Valdobbiadene Prosecco Superiore', nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Anderson Valley', nan)
# ('Vino Spumante', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Chalone', 'Central Coast')
# ('Yarra Valley', nan)
# ('Santa Maria Valley', 'Central Coast')
# ('Mendoza', nan)
# ('Paso Robles', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# ('McLaren Vale', nan)
# ('Sta. Rita Hills', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# ('Chianti Classico', nan)
# (nan, nan)
# ('Barossa Valley', nan)
# ('Sancerre', nan)
# (nan, nan)
# ('La Consulta', nan)
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# ('Russian River Valley', 'Sonoma')
# (nan, nan)
# (nan, nan)
# ('Toscana', nan)
# ('Côtes du Jura', nan)
# ('Santa Lucia Highlands', 'Central Coast')
# (nan, nan)
# ('Chianti Classico', nan)
# ('Anderson Valley', nan)
# ('Paso Robles', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Chianti Classico', nan)
# ('Bonnezeaux', nan)
# ('Russian River Valley', 'Sonoma')
# ('Russian River Valley', 'Sonoma')
# ('Yorkville Highlands', 'North Coast')
# ('Knights Valley', 'Sonoma')
# ('Alsace', nan)
# ('Monticello', nan)
# ('Côtes de Provence', nan)
# ('Napa Valley', 'Napa')
# ('Trentino', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Santa Ynez Valley', 'Central Coast')
# ('Sta. Rita Hills', 'Central Coast')
# ("Coteaux d'Aix-en-Provence", nan)
# ('Carneros', 'Napa-Sonoma')
# ('Alsace', nan)
# ('Soave', nan)
# ('Trentino', nan)
# ('Russian River Valley', 'Sonoma')
# (nan, nan)
# ('Napa Valley', 'Napa')
# (nan, nan)
# ('Russian River Valley', 'Sonoma')
# (nan, nan)
# ('Santa Barbara County', 'Central Coast')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Amarone della Valpolicella', nan)
# ('Central Coast', 'Central Coast')
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('Russian River Valley', 'Sonoma')
# ('Rutherford', 'Napa')
# ('Finger Lakes', 'Finger Lakes')
# ('Margaux', nan)
# ('Saint-Émilion', nan)
# ('Saint-Émilion', nan)
# ('Médoc', nan)
# ('Saint-Estèphe', nan)
# ('Côtes de Provence', nan)
# ('Pessac-Léognan', nan)
# ('Pessac-Léognan', nan)
# ('Saint-Julien', nan)
# ('Saint-Émilion', nan)
# ('Haut-Médoc', nan)
# ('Côtes de Provence', nan)
# ('Côtes de Provence', nan)
# ('Côtes de Provence', nan)
# ('Médoc', nan)
# ('Médoc', nan)
# ('Médoc', nan)
# ('Médoc', nan)
# (nan, nan)
# ('Anderson Valley', nan)
# ('Howell Mountain', 'Napa')
# ('Anderson Valley', nan)
# (nan, nan)
# ('Atlas Peak', 'Napa')
# ('Anderson Valley', nan)
# (nan, nan)
# (nan, nan)
# ('Toscana', nan)
# ...
# ('Muscadet Sèvre et Maine', nan)
# ('Sonoma Valley', 'Sonoma')
# ('Napa Valley', 'Napa')
# ('Santa Maria Valley', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Delle Venezie', nan)
# ('Mendoza', nan)
# ('Russian River Valley', 'Sonoma')
# ('Mâcon-Verze', nan)
# ('Delle Venezie', nan)
# (nan, nan)
# ('Colli Orientali del Friuli', nan)
# ('Mendoza', nan)
# ('Yakima Valley', 'Columbia Valley')
# ('Vigneti delle Dolomiti', nan)
# ('Yecla', nan)
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Utiel-Requena', nan)
# ('Alto Adige', nan)
# ('Crozes-Hermitage', nan)
# (nan, nan)
# ('Sonoma County', 'Sonoma')
# ('Napa Valley', 'Napa')
# ('Sta. Rita Hills', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Tasmania', nan)
# ('Alto Adige', nan)
# ('Alto Adige', nan)
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Napa Valley', 'Napa')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Carneros', 'Napa-Sonoma')
# ('Santa Ynez Valley', 'Central Coast')
# ('Napa Valley', 'Napa')
# ('Russian River Valley', 'Sonoma')
# ('Côtes de Provence', nan)
# ('Côtes de Provence', nan)
# ('Côtes de Provence', nan)
# ('Côtes de Provence', nan)
# ('San Juan', nan)
# ('Prosecco del Veneto', nan)
# ('Mendoza', nan)
# ('South Eastern Australia', nan)
# ('Rioja', nan)
# ('Prosecco di Valdobbiadene', nan)
# ('Savigny-lès-Beaune', nan)
# ('Luján de Cuyo', nan)
# ('Prosecco di Valdobbiadene', nan)
# ('Prosecco di Valdobbiadene', nan)
# ('Prosecco di Conegliano', nan)
# ('Russian River Valley', 'Sonoma')
# ('Prosecco del Veneto', nan)
# ('Prosecco del Veneto', nan)
# ('Marca Trevigiana', nan)
# ('Prosecco di Valdobbiadene', nan)
# (nan, nan)
# (nan, nan)
# ('Prosecco del Veneto', nan)
# (nan, nan)
# ('Adelaide Hills', nan)
# (nan, nan)
# (nan, nan)
# ('Mendocino County', nan)
# ('Alexander Valley', 'Sonoma')
# ('Bardolino Superiore', nan)
# ('California', 'California Other')
# ('Temecula Valley', 'South Coast')
# ('Clare Valley', nan)
# ('Barbaresco', nan)
# ('Sierra Foothills', 'Sierra Foothills')
# ('Sierra Foothills', 'Sierra Foothills')
# ('Montefalco Sagrantino', nan)
# ('Barolo', nan)
# ('Santa Lucia Highlands', 'Central Coast')
# (nan, nan)
# ('Monticello', nan)
# (nan, nan)
# (nan, nan)
# ('Valpolicella', nan)
# (nan, nan)
# ('North Coast', 'North Coast')
# (nan, nan)
# ('Santa Barbara County', 'Central Coast')
# ('Amador County', 'Sierra Foothills')
# (nan, nan)
# ('Barolo', nan)
# ('Barossa Valley', nan)
# (nan, nan)
# ('Alexander Valley', 'Sonoma')
# (nan, nan)
# (nan, nan)
# ('California', 'California Other')
# ('Santa Barbara County', 'Central Coast')
# ('California', 'California Other')
# ('Savoie', nan)
# (nan, nan)
# ('North Coast', 'North Coast')
# (nan, nan)
# (nan, nan)
# ('Barossa Valley', nan)
# ('McLaren Vale', nan)
# ('Barolo', nan)
# ('California', 'California Other')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Yolo County', 'Central Valley')
# ('Santa Barbara County', 'Central Coast')
# ('California', 'California Other')
# (nan, nan)
# ('Yakima Valley', 'Columbia Valley')
# (nan, nan)
# ('Virginia', nan)
# ('Valpolicella Classico Superiore Ripasso', nan)
# ('Lake County', nan)
# (nan, nan)
# ('Valpolicella Superiore', nan)
# ('Russian River Valley', 'Sonoma')
# ('Champagne', nan)
# ('Santa Lucia Highlands', 'Central Coast')
# ('Santa Barbara County', 'Central Coast')
# ('Carneros', 'Napa-Sonoma')
# ('Champagne', nan)
# ('Franciacorta', nan)
# ('Niagara Peninsula', nan)
# ('Montagne-Saint-Émilion', nan)
# ('Vin de Liqueur', nan)
# ('Chehalem Mountains', 'Willamette Valley')
# ('Carneros', 'Napa-Sonoma')
# ('Santa Ynez Valley', 'Central Coast')
# (nan, nan)
# ('Sonoma County', 'Sonoma')
# ('California', 'California Other')
# ('Ribbon Ridge', 'Willamette Valley')
# (nan, nan)
# ('Edna Valley', 'Central Coast')
# ('Willamette Valley', 'Willamette Valley')
# ('Santa Maria Valley', 'Central Coast')
# ('Short Hills Bench', nan)
# (nan, nan)
# ('California', 'California Other')
# (nan, nan)
# ('Bandol', nan)
# ('Dundee Hills', 'Willamette Valley')
# ("Crémant d'Alsace", nan)
# ("Moscato d'Asti", nan)
# ('Sonoma County', 'Sonoma')
# ('Champagne', nan)
# ('San Benito County', 'Central Coast')
# ('California', 'California Other')
# ('Toro', nan)
# ('Penedès', nan)
# ('Alsace', nan)
# ('Alsace', nan)
# ('Champagne', nan)
# ('Champagne', nan)
# ('Gavi', nan)
# ("Crémant d'Alsace", nan)
# (nan, nan)
# ('Lodi', 'Central Valley')
# ('Trento', nan)
# ('Livermore Valley', 'Central Coast')
# ('Navarra', nan)
# ('Chalone', 'Central Coast')
# ('Champagne', nan)
# ('Barolo', nan)
# ('Champagne', nan)
# (nan, nan)
# ('Champagne', nan)
# ('Blaye Côtes de Bordeaux', nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Morellino di Scansano', nan)
# ('Amarone della Valpolicella Classico', nan)
# ('Blaye Côtes de Bordeaux', nan)
# ('Lalande de Pomerol', nan)
# ('Champagne', nan)
# ('Vin de France', nan)
# ('Shenandoah Valley (CA)', 'Sierra Foothills')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Niagara Peninsula', nan)
# ('Champagne', nan)
# ('Paso Robles', 'Central Coast')
# ('Lake County', nan)
# ('Graves', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Savoie', nan)
# ('Roussette de Savoie', nan)
# ('Carneros', 'Napa-Sonoma')
# ('Montagny', nan)
# ('Napa Valley', 'Napa')
# ('Champagne', nan)
# ('Umpqua Valley', 'Southern Oregon')
# ('Chehalem Mountains', 'Willamette Valley')
# ('Willamette Valley', 'Willamette Valley')
# ('Dry Creek Valley', 'Sonoma')
# ('Lodi', 'Central Valley')
# ('Russian River Valley', 'Sonoma')
# ('Santa Lucia Highlands', 'Central Coast')
# ('Saint-Émilion', nan)
# ('Saint-Julien', nan)
# ('Rutherford', 'Napa')
# (nan, nan)
# ('Sonoma Coast', 'Sonoma')
# ('Barolo', nan)
# ('California Other', nan)
# ('Santa Cruz Mountains', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# (nan, nan)
# ('Paso Robles', 'Central Coast')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Santa Barbara County', 'Central Coast')
# ('Red Mountain', 'Columbia Valley')
# ('Barolo', nan)
# ('Russian River Valley', 'Sonoma')
# ('Sonoma Coast', 'Sonoma')
# ('Green Valley', 'Sonoma')
# ('Barolo', nan)
# ('Anderson Valley', nan)
# ('Anderson Valley', nan)
# ('Barolo', nan)
# ('Santa Margarita Ranch', 'Central Coast')
# ('Barolo', nan)
# ('Tavel', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Central Coast', 'Central Coast')
# ('Paso Robles', 'Central Coast')
# ('Chianti Classico', nan)
# ('Napa Valley', 'Napa')
# ('Napa Valley', 'Napa')
# ('Brunello di Montalcino', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Okanagan Valley', nan)
# ('Dry Creek Valley', 'Sonoma')
# ('Russian River Valley', 'Sonoma')
# ('Brunello di Montalcino', nan)
# ('Brunello di Montalcino', nan)
# ('Ballard Canyon', 'Central Coast')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Ribeira Sacra', nan)
# ('Cour-Cheverny', nan)
# (nan, nan)
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Bourgogne Hautes Côtes de Beaune', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Brunello di Montalcino', nan)
# ('Russian River Valley', 'Sonoma')
# ('Sancerre', nan)
# ('Russian River Valley', 'Sonoma')
# ('Tavel', nan)
# ('Carneros', 'Napa-Sonoma')
# ('Monterey County', 'Central Coast')
# ('Maremma Toscana', nan)
# ('Lodi', 'Central Valley')
# ('Napa Valley', 'Napa')
# ('Mendoza', nan)
# ('Rioja', nan)
# ('Russian River Valley', 'Sonoma')
# (nan, nan)
# ('Livermore Valley', 'Central Coast')
# ('Toscana', nan)
# (nan, nan)
# ('Mendoza', nan)
# (nan, nan)
# ('Carneros', 'Napa-Sonoma')
# ('Rioja', nan)
# ('California', 'California Other')
# ('Mendoza', nan)
# ('San Antonio Valley', 'Central Coast')
# ('Mendoza', nan)
# ('Argentina', nan)
# (nan, nan)
# ('Knights Valley', 'Sonoma')
# ('Mendoza', nan)
# (nan, nan)
# ('Livermore Valley', 'Central Coast')
# ('Toscana', nan)
# ('Dry Creek Valley', 'Sonoma')
# ('Lodi', 'Central Valley')
# ('Santa Cruz Mountains', 'Central Coast')
# ('Greco di Tufo', nan)
# ('St. Helena', 'Napa')
# ('Cafayate', nan)
# ('Arroyo Grande Valley', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Mendocino County', nan)
# ('Cahors', nan)
# ('Bergerac Sec', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Rías Baixas', nan)
# ('Anderson Valley', nan)
# ('Edna Valley', 'Central Coast')
# ('Vacqueyras', nan)
# ('Châteauneuf-du-Pape', nan)
# ('Cafayate', nan)
# ('Paso Robles', 'Central Coast')
# ('Luján de Cuyo', nan)
# ('Napa Valley', 'Napa')
# ('Virginia', nan)
# ('Muscadet Sèvre et Maine', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Sonoma Coast', 'Sonoma')
# ('Muscadet Sèvre et Maine', nan)
# ('Bierzo', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Oregon', 'Oregon Other')
# ('Chablis', nan)
# ('Beaune', nan)
# ('Napa Valley', 'Napa')
# ('Beaune', nan)
# ('Sonoma County', 'Sonoma')
# ('Willamette Valley', nan)
# ('Mokelumne River', 'Central Valley')
# ('Savigny-lès-Beaune', nan)
# ('Corton-Charlemagne', nan)
# ('Corton Vergennes', nan)
# ('Nuits-St.-Georges', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Barolo', nan)
# (nan, nan)
# (nan, nan)
# ('Uco Valley', nan)
# ('McMinnville', 'Willamette Valley')
# ('Barbaresco', nan)
# (nan, nan)
# ('Mendoza', nan)
# ('Mt. Harlan', 'Central Coast')
# ('Russian River Valley', 'Sonoma')
# (nan, nan)
# ('Barbaresco', nan)
# ('Santa Barbara County', 'Central Coast')
# (nan, nan)
# ('Chambolle-Musigny', nan)
# (nan, nan)
# ('Puligny-Montrachet', nan)
# ('Sta. Rita Hills', 'Central Coast')
# ('Red Mountain', 'Columbia Valley')
# ('California', 'California Other')
# ('Amarone della Valpolicella', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Amarone della Valpolicella', nan)
# ('Navarra', nan)
# ('California', 'California Other')
# ('California', 'California Other')
# ('Alsace', nan)
# ('Rattlesnake Hills', 'Columbia Valley')
# ('Lodi', 'Central Valley')
# ('Valpolicella Classico Superiore Ripasso', nan)
# ('Sonoma Coast', 'Sonoma')
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Côtes de Duras', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Napa Valley', 'Napa')
# ('Mendoza', nan)
# ('Sonoma County', 'Sonoma')
# ('Virginia', nan)
# ('Côtes du Roussillon', nan)
# ('Mendoza', nan)
# ('Virginia', nan)
# ('Bourgogne', nan)
# ('Friuli Isonzo', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Alsace', nan)
# ('Sonoma Valley', 'Sonoma')
# ('Spring Mountain District', 'Napa')
# ('Napa Valley', 'Napa')
# ('Champagne', nan)
# ('Carneros', 'Napa-Sonoma')
# ('Etna', nan)
# ('Irpinia', nan)
# ('Priorat', nan)
# (nan, nan)
# ('Sonoma County-Napa County', 'Napa-Sonoma')
# ('Adelaide Hills', nan)
# ('Rioja', nan)
# ('Napa Valley', 'Napa')
# ('Rioja', nan)
# ('Ribera del Duero', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Washington', 'Washington Other')
# ('Chehalem Mountains', 'Willamette Valley')
# ('Napa Valley', 'Napa')
# ('Etna', nan)
# ('Willamette Valley', 'Willamette Valley')
# ('Rioja', nan)
# ('Rattlesnake Hills', 'Columbia Valley')
# ('Santa Ynez Valley', 'Central Coast')
# ('Romagna', nan)
# ('Russian River Valley', 'Sonoma')
# (nan, nan)
# ('Champagne', nan)
# ('Paso Robles', 'Central Coast')
# ('Willamette Valley', 'Willamette Valley')
# ('Willamette Valley', 'Willamette Valley')
# ('Côtes de Provence', nan)
# ('Côtes de Provence', nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Terre Siciliane', nan)
# ('Rueda', nan)
# ('Mendoza', nan)
# (nan, nan)
# ('Alsace', nan)
# ('Alsace', nan)
# ('Red Mountain', 'Columbia Valley')
# ('Ancient Lakes', 'Columbia Valley')
# ('Côtes de Provence', nan)
# ('Côtes de Provence', nan)
# ('Paestum', nan)
# ('Côtes de Provence', nan)
# ('Russian River Valley', 'Sonoma')
# ('Dry Creek Valley', 'Sonoma')
# ('Alsace', nan)
# ('Monticello', nan)
# (nan, nan)
# ('Rioja', nan)
# ('Cayuga Lake', 'Finger Lakes')
# ('Santa Ynez Valley', 'Central Coast')
# ('Paso Robles', 'Central Coast')
# ('Sonoma Coast', 'Sonoma')
# ('Finger Lakes', 'Finger Lakes')
# (nan, nan)
# (nan, nan)
# ('Paso Robles', 'Central Coast')
# ('Málaga', nan)
# ('Salta', nan)
# ('Amarone della Valpolicella Classico', nan)
# ('Chalk Hill', 'Sonoma')
# ('Savigny-lès-Beaune', nan)
# ('Mercurey', nan)
# ('Russian River Valley', 'Sonoma')
# ('Yakima Valley', 'Columbia Valley')
# ('Finger Lakes', 'Finger Lakes')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Montagny', nan)
# ('Volnay', nan)
# ('Finger Lakes', 'Finger Lakes')
# ('Rioja', nan)
# ('Red Mountain', 'Columbia Valley')
# ('Finger Lakes', 'Finger Lakes')
# ('Sonoma Valley', 'Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Ribera del Duero', nan)
# ('Amarone della Valpolicella Classico', nan)
# ('Monticello', nan)
# ('Valpolicella Classico Superiore Ripasso', nan)
# ('Seneca Lake', 'Finger Lakes')
# ('Jumilla', nan)
# ('Meursault', nan)
# ('Valpolicella Classico Superiore Ripasso', nan)
# ('Edna Valley', 'Central Coast')
# ('Amarone della Valpolicella Classico', nan)
# ('Valpolicella Classico Superiore Ripasso', nan)
# ('Finger Lakes', 'Finger Lakes')
# (nan, nan)
# ('Roero', nan)
# ('Mendocino', nan)
# ('Barbaresco', nan)
# (nan, nan)
# ('Chambolle-Musigny', nan)
# (nan, nan)
# ('Barolo', nan)
# ('Crémant de Bourgogne', nan)
# ('Columbia Gorge (WA)', 'Washington Other')
# ('Chambolle-Musigny', nan)
# ('Volnay', nan)
# ('Nuits-St.-Georges', nan)
# ('Barbaresco', nan)
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Barbaresco', nan)
# ('Chassagne-Montrachet', nan)
# ('Barolo', nan)
# ('Côte de Beaune-Villages', nan)
# ('Barolo', nan)
# (nan, nan)
# (nan, nan)
# ('Rattlesnake Hills', 'Columbia Valley')
# (nan, nan)
# (nan, nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Diamond Mountain District', 'Napa')
# ("Vin de Pays d'Oc", nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Médoc', nan)
# ('Rattlesnake Hills', 'Columbia Valley')
# (nan, nan)
# ('Salento', nan)
# ('Colli di Luni', nan)
# ('Morellino di Scansano', nan)
# (nan, nan)
# ('Rattlesnake Hills', 'Columbia Valley')
# ('Napa Valley', 'Napa')
# (nan, nan)
# ('Veneto', nan)
# ('Campania', nan)
# ('Sicilia', nan)
# ('Sicilia', nan)
# ('Alsace', nan)
# ('Napa Valley', 'Napa')
# ('Carneros', 'Napa-Sonoma')
# ('Rías Baixas', nan)
# ('Carneros', 'Napa-Sonoma')
# ('Anderson Valley', nan)
# (nan, nan)
# (nan, nan)
# ('Horse Heaven Hills', 'Columbia Valley')
# ('Green Valley', 'Sonoma')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Yakima Valley', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Russian River Valley', 'Sonoma')
# ('California', 'California Other')
# ('Ribera del Duero', nan)
# ('Alsace', nan)
# ('Anderson Valley', nan)
# ('Cahors', nan)
# ('North Fork of Long Island', 'Long Island')
# ('Beaujolais-Villages', nan)
# ('Beaujolais', nan)
# ('Alsace', nan)
# ('Russian River Valley', 'Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Russian River Valley', 'Sonoma')
# ('Rueda', nan)
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Rioja', nan)
# ('Santa Ynez Valley', 'Central Coast')
# ('Mendoza', nan)
# ('Mendoza', nan)
# ('Santa Lucia Highlands', 'Central Coast')
# ('Saint-Péray', nan)
# ('Luján de Cuyo', nan)
# ('Calistoga', 'Napa')
# ('Brunello di Montalcino', nan)
# ('Soave Classico', nan)
# ('Côtes du Marmandais', nan)
# ('Green Valley', 'Sonoma')
# ('Alexander Valley', 'Sonoma')
# ('Paso Robles', 'Central Coast')
# ('Paso Robles', 'Central Coast')
# ('Napa Valley', 'Napa')
# (nan, nan)
# (nan, nan)
# ('Rueda', nan)
# ('Saint-Péray', nan)
# ('Chalk Hill', 'Sonoma')
# ('Châteauneuf-du-Pape', nan)
# ('Napa Valley', 'Napa')
# (nan, nan)
# (nan, nan)
# ('San Luis Obispo County', 'Central Coast')
# (nan, nan)
# (nan, nan)
# ('Sonoma Coast', 'Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Dry Creek Valley', 'Sonoma')
# ('Columbia Valley (WA)', 'Columbia Valley')
# (nan, nan)
# ('Mendoza', nan)
# (nan, nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Sta. Rita Hills', 'Central Coast')
# ('Mendoza', nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Uco Valley', nan)
# ('Walla Walla Valley (WA)', 'Columbia Valley')
# ('Columbia Valley (WA)', 'Columbia Valley')
# ('Priorat', nan)
# ('Prosecco Superiore di Cartizze', nan)
# ('Ribera del Duero', nan)
# ('Grands-Echezeaux', nan)
# ('Uco Valley', nan)
# (nan, nan)
# (nan, nan)
# ('Columbia Valley-Walla Walla Valley', 'Columbia Valley')
# ('Pommard', nan)
# (nan, nan)
# ('Luján de Cuyo', nan)
# (nan, nan)
# ('Mendocino', nan)
# ('Mendocino County', nan)
# ('Sonoma County', 'Sonoma')
# ('Sicilia', nan)
# (nan, nan)
# ('Santa Ynez Valley', 'Central Coast')
# (nan, nan)
# ('Terre Siciliane', nan)
# ('San Juan', nan)
# ('Napa Valley', 'Napa')
# ('Napa Valley', 'Napa')
# ('Alsace', nan)
# ('Chiles Valley', 'Napa')
# (nan, nan)
# (nan, nan)
# (nan, nan)
# (nan, nan)
# ('Rioja', nan)
# (nan, nan)
# ('Alsace', nan)
# (nan, nan)
# ('Sicilia', nan)
# ('Sicilia', nan)
# (nan, nan)
# ('Alsace', nan)
# ('Alsace', nan)
# (nan, nan)
# ('Oregon', 'Oregon Other')
# ('Alsace', nan)
# ('Alsace', nan)
# ('Alsace', nan)

# %%
drop_columns = ['region_2','taster_twitter_handle','taster_name','region_1']
wine_df.drop(columns = drop_columns, inplace = True)
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province                                              title  \
# 0       Sicily & Sardinia                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1                   Douro      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2                  Oregon      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                Michigan  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4                  Oregon  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# ...                   ...                                                ...
# 129966              Mosel  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
# 129967             Oregon                  Citation 2004 Pinot Noir (Oregon)
# 129968             Alsace  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129969             Alsace      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970             Alsace  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
#                variety                                    winery
# 0          White Blend                                   Nicosia
# 1       Portuguese Red                       Quinta dos Avidagos
# 2           Pinot Gris                                 Rainstorm
# 3             Riesling                                St. Julian
# 4           Pinot Noir                              Sweet Cheeks
# ...                ...                                       ...
# 129966        Riesling  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967      Pinot Noir                                  Citation
# 129968  Gewürztraminer                           Domaine Gresser
# 129969      Pinot Gris                      Domaine Marcel Deiss
# 129970  Gewürztraminer                          Domaine Schoffit
#
# [129971 rows x 9 columns]

# %%
wine_df.price = wine_df.price.fillna(wine_df.price.mean())

# %%
drop_data = ['country','designation','province','variety']
for i in wine_df:
    wine_df = wine_df[wine_df[i].notna()]

# %%
print('total null value in all columns')
wine_df.isna().sum()
# Out:
# total null value in all columns
# country        0
# description    0
# designation    0
# points         0
# price          0
# province       0
# title          0
# variety        0
# winery         0
# dtype: int64

# %%
print("all columns unique elements")
for i in wine_df.columns:
    print(i, wine_df[i].nunique())
# Out:
# all columns unique elements
# country 42
# description 85379
# designation 37954
# points 21
# price 331
# province 406
# title 84502
# variety 641
# winery 12538

# %%
ordinal_col = ['country','province','variety']
wine_df[ordinal_col] = wine_df[ordinal_col].apply(LabelEncoder().fit_transform)

# %%
wine_df
# Out:
#         country                                        description  \
# 0            22  Aromas include tropical fruit, broom, brimston...
# 1            31  This is ripe and fruity, a wine that is smooth...
# 3            39  Pineapple rind, lemon pith and orange blossom ...
# 4            39  Much like the regular bottling from 2012, this...
# 5            36  Blackberry and raspberry aromas show a typical...
# ...         ...                                                ...
# 129964       15  Initially quite muted, this wine slowly develo...
# 129965       15  While it's rich, this beautiful dry wine also ...
# 129966       17  Notes of honeysuckle and cantaloupe sweeten th...
# 129968       15  Well-drained gravel soil gives this wine its c...
# 129970       15  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points      price  province  \
# 0                                 Vulkà Bianco      87  35.363389       316
# 1                                     Avidagos      87  15.000000       104
# 3                         Reserve Late Harvest      87  13.000000       208
# 4           Vintner's Reserve Wild Child Block      87  65.000000       256
# 5                                 Ars In Vitro      87  15.000000       250
# ...                                        ...     ...        ...       ...
# 129964            Domaine Saint-Rémy Herrenweg      90  35.363389        11
# 129965             Seppi Landmann Vallée Noble      90  28.000000        11
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90  28.000000       222
# 129968                                   Kritt      90  30.000000        11
# 129970           Lieu-dit Harth Cuvée Caroline      90  21.000000        11
#
#                                                     title  variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)      627
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)      407
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...      434
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      398
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...      538
# ...                                                   ...      ...
# 129964  Domaine Ehrhart 2013 Domaine Saint-Rémy Herren...      194
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...      394
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...      434
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      194
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      194
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# 5                                         Tandem
# ...                                          ...
# 129964                           Domaine Ehrhart
# 129965                   Domaine Rieflé-Landmann
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129968                           Domaine Gresser
# 129970                          Domaine Schoffit
#
# [92454 rows x 9 columns]

# %%
# numeric_data = wine_df[['country','price','province','variety','points']]
numeric_data = wine_df[['country','price','province','variety','points']]
x = numeric_data.drop(columns = 'points')
y = numeric_data['points']

# %%
linear = LinearRegression()
score = cross_val_score(linear, x, y, cv = 5).mean()
print(f'with only numeric data score is {score}')
# Out:
# with only numeric data score is 0.19459515770582686

# %%
CountVec = CountVectorizer(stop_words='english')
Count_data = CountVec.fit_transform(wine_df.description)

# cv_dataframe=pd.DataFrame(Count_data.toarray(),columns=CountVec.get_feature_names())
print()

# %%
x = Count_data
y = numeric_data['points']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size = 0.80)

# %%
linear = LinearRegression()
linear.fit(X_train, y_train)
linear_score = linear.score(X_test, y_test)
print(f'with Count Vectorizer with not ngram hyperParameter score is {linear_score}')
# Out:
# with Count Vectorizer with not ngram hyperParameter score is 0.5594071496265465

# %%
Tf_Vec = CountVectorizer(stop_words='english', ngram_range=(1, 3))
Tf_data = CountVec.fit_transform(wine_df.description)

# %%
x = Tf_data
y = numeric_data['points']
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size = 0.80)

# %%
regulized_linear_model = {
    'liner': LinearRegression(),
    'ridge': Ridge(),
    'Lasso': Lasso()
}

# %%
model_score = {}
for i in regulized_linear_model:
    linear = regulized_linear_model[i]
    linear.fit(X_train, y_train)
    model_score[i] = linear.score(X_test, y_test)
print(print(f'CountVectorizer with ngram hyperParameter score is \n{model_score}'))
# Out:
# CountVectorizer with ngram hyperParameter score is
# {'liner': 0.5694240215359093, 'ridge': 0.6734025397737551, 'Lasso': -6.670501608851964e-07}
# None

# %%
tf_vec = TfidfVectorizer(lowercase=True, stop_words='english', ngram_range=(1, 3))
Tf_vsc = CountVec.fit_transform(wine_df.description)

# %%
x = Tf_vsc
y = numeric_data['points']
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size = 0.80)

# %%
tf_score = {}
for i in regulized_linear_model:
    linear = regulized_linear_model[i]
    linear.fit(X_train, y_train)
    tf_score[i] = linear.score(X_test, y_test)
print(print(f'TfidfVectorizer with ngram hyperParameter score linearmodels score is \n{tf_score}'))
# Out:
# TfidfVectorizer with ngram hyperParameter score linearmodels score is
# {'liner': 0.5566794115838426, 'ridge': 0.6686426052717533, 'Lasso': -0.0006866869085992988}
# None

# %%
main_df = wine_df[['country', 'price', 'province', 'variety','description']]
main_points = wine_df['points']

# %%
tf_vec = TfidfVectorizer(lowercase=True, stop_words='english', ngram_range=(1, 3))
main_df = CountVec.fit_transform(wine_df.description)

# %%
x = main_df
y = main_points
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size = 0.80)

# %%
main_model_score = {}
for i in regulized_linear_model:
    linear = regulized_linear_model[i]
    linear.fit(X_train, y_train)
    main_model_score[i] = linear.score(X_test, y_test)
print(f'all numeric data + description columns\nTfidfVectorizer with ngram hyperParameter score in linear models score is \n{main_model_score}')
# Out:
# all numeric data + description columns
# TfidfVectorizer with ngram hyperParameter score in linear models score is
# {'liner': 0.5467624712347319, 'ridge': 0.6663270373155953, 'Lasso': -7.558444930122477e-05}

# %% [markdown]
# # TASK 2

# %%
main_df = wine_df[['country', 'price', 'province', 'variety','description']]
main_points = wine_df['points']

# %%
word2Vec = Word2Vec(main_df)
# main_df = word2Vec.fit_transform(main_df['description'])
word2Vec

# %%
df = pd.DataFrame(word2Vec)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12960\3494788958.py in <module>
# ----> 1 df = pd.DataFrame(word2Vec)
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
x = word2Vec
y = main_points
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size = 0.80)

# %%
linear = LinearRegression()
linear.fit(X_train, y_train)
linear_score = linear.score(X_test, y_test)
linear_score
